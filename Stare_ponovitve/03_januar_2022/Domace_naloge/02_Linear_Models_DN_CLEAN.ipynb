# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Vaja: </b>
# Uvozite dataset <i>weatherAUS.csv</i>, ki vsebuje vremenske indikatorje.
#
# Končna naloga je, da ustvarite nek model, ki bo napovedoval <b>RainTomorrow</b> - ali bo deževalo jutri ali ne.
#
# Za primerjavo - naš najboljši model je imel sledeče karakteristike:
#
#     Model:       LogisticRegression
#     .score():    0.84
#     C:           100
#     max_iter:    100000
#     solver:      'liblinear'
# </div>

# %%
import pandas as pd
data = pd.read_csv("DN_data/weatherAUS.csv", index_col=0)
data.head(10)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0     13.4     22.9       0.6          4.8       8.4           44.0
# 1      7.4     25.1       0.0          4.8       8.4           44.0
# 2     12.9     25.7       0.0          4.8       8.4           46.0
# 3      9.2     28.0       0.0          4.8       8.4           24.0
# 4     17.5     32.3       1.0          4.8       8.4           41.0
# 5     14.6     29.7       0.2          4.8       8.4           56.0
# 6     14.3     25.0       0.0          4.8       8.4           50.0
# 7      7.7     26.7       0.0          4.8       8.4           35.0
# 8      9.7     31.9       0.0          4.8       8.4           80.0
# 9     13.1     30.1       1.4          4.8       8.4           28.0
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0          20.0          24.0         71.0         22.0       1007.7
# 1           4.0          22.0         44.0         25.0       1010.6
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# Izbrišite vrstice, ki nimajo vrednosti.
# </div>

# %%
# Rešitev

# %% [markdown]
# <div class="alert alert-block alert-info">
# Stolpec <b>RainTomorrow</b> spremenite tako, da <i>No</i> vrednosti spremenite v <i>0</i> in <i>Yes</i> vrednosti spremenite v <i>1</i>.
#
# Nato stolpec pretvorite v <i>integer</i>.
# </div>

# %%
# Rešitev

# %% [markdown]
# <div class="alert alert-block alert-info">
# Ustvarite model.
# </div>

# %%
# Rešitev
