# %% [markdown]
# #  Grid-Searching Which Model To Use

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

pipe = Pipeline([('preprocessing', StandardScaler()), ('classifier', SVC())])

# %%
from sklearn.ensemble import RandomForestClassifier

param_grid = [
    {'classifier': [SVC()], 
     'preprocessing': [StandardScaler(), None],
     'classifier__gamma': [0.001, 0.01, 0.1, 1, 10, 100],
     'classifier__C': [0.001, 0.01, 0.1, 1, 10, 100]},
    {'classifier': [RandomForestClassifier(n_estimators=100)],
     'preprocessing': [None], 
     'classifier__max_features': [1, 2, 3]}]

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import GridSearchCV

cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, random_state=0)

grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)

print(f"Best params:\n{grid.best_params_}\n")
print(f"Best cross-validation score: {grid.best_score_:.2f}")
print(f"Test-set score: {grid.score(X_test, y_test):.2f}")
# Out:
# Best params:
# {'classifier': SVC(C=10, gamma=0.01), 'classifier__C': 10, 'classifier__gamma': 0.01, 'preprocessing': StandardScaler()}
#
# Best cross-validation score: 0.99
# Test-set score: 0.98

# %% [markdown]
# ## Vaja

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, Normalizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
iris_df=load_iris()

X_train, X_test, y_train, y_test = train_test_split(iris_df.data ,iris_df.target, test_size=0.2, random_state=0)

# %%
pipeline_lr = make_pipeline(StandardScaler(), PCA(n_components=2), LogisticRegression(random_state=0))
model = pipeline_lr.fit(X_train, y_train)
final_score = model.score(X_test,y_test)
print(f"Final score - {model.steps}: {final_score:.2}")
# Out:
# Final score - [('standardscaler', StandardScaler()), ('pca', PCA(n_components=2)), ('logisticregression', LogisticRegression(random_state=0))]: 0.87

# %%
def run_grid_pipeline_iris_df():
    iris_df = load_iris()
    X_train, X_test, y_train, y_test = train_test_split(iris_df.data ,iris_df.target, test_size=0.25, random_state=0)
    
    # start pipeline
    pipe = Pipeline([('preprocessing_scaling', StandardScaler()), 
                     ('predprocessing_pca', PCA()),
                     ('classifier', LogisticRegression(random_state=0))])

    # PARAMETERS
    param_grid = [
        {'classifier': [LogisticRegression(max_iter=10000, solver="saga")], 
         'predprocessing_pca': [PCA(n_components=2), None],
         'preprocessing_scaling': [MinMaxScaler(), StandardScaler(), RobustScaler(), Normalizer(), None],
         'classifier__penalty': ["l1", "l2"], 
        },
        {'classifier': [DecisionTreeClassifier(random_state=0)], 
         'predprocessing_pca': [PCA(n_components=2), None],
         'preprocessing_scaling': [MinMaxScaler(), StandardScaler(), RobustScaler(), Normalizer(), None],  
        },
        {'classifier': [SVC()], 
         'predprocessing_pca': [PCA(n_components=2), None],
         'preprocessing_scaling': [MinMaxScaler(), StandardScaler(), RobustScaler(), Normalizer(), None],
        },
        {'classifier': [KNeighborsClassifier()], 
         'predprocessing_pca': [PCA(n_components=2), None],
         'preprocessing_scaling': [MinMaxScaler(), StandardScaler(), RobustScaler(), Normalizer(), None],
        },
    ]

    # run grid search
    grid = GridSearchCV(pipe, param_grid, cv=5)
    grid.fit(X_train, y_train)
    
    print(f"Best params:\n{grid.best_params_}\n")
    print(f"Test-set score: {grid.score(X_test, y_test):.2f}")
    results = pd.DataFrame(grid.cv_results_)
    # confusion matrix
    prediction = grid.predict(X_test)
    confusion = confusion_matrix(y_test, prediction)
    print(f"Confusion matrix:\n{confusion}\n")
    return results

# %%
grids_result = run_grid_pipeline_iris_df()
# Out:
# Best params:
# {'classifier': DecisionTreeClassifier(random_state=0), 'predprocessing_pca': PCA(n_components=2), 'preprocessing_scaling': Normalizer()}
#
# Test-set score: 0.97
# Confusion matrix:
# [[13  0  0]
#  [ 0 15  1]
#  [ 0  0  9]]

# %%
grids_result
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003285      0.000565         0.000699        0.000076
# 1        0.004829      0.000347         0.000686        0.000032
# 2        0.005521      0.000315         0.000676        0.000013
# 3        0.003535      0.000384         0.000803        0.000024
# 4        0.004960      0.000280         0.000551        0.000019
# 5        0.017072      0.005978         0.000556        0.000022
# 6        0.019870      0.005984         0.000620        0.000125
# 7        0.017269      0.003563         0.000563        0.000023
# 8        0.004160      0.000122         0.000613        0.000010
# 9        0.120960      0.017948         0.000422        0.000013
# 10       0.002583      0.000051         0.000634        0.000021
# 11       0.003165      0.000061         0.000646        0.000026
# 12       0.004153      0.000049         0.000629        0.000006
# 13       0.002619      0.000067         0.000735        0.000020
# 14       0.003109      0.000075         0.000518        0.000010
# 15       0.002516      0.000082         0.000525        0.000021
# 16       0.003441      0.000063         0.000509        0.000001
# 17       0.004280      0.000069         0.000509        0.000001
# 18       0.002433      0.000116         0.000608        0.000002
# 19       0.060802      0.001859         0.000396        0.000001
# 20       0.001874      0.000142         0.000651        0.000021
# 21       0.001967      0.000050         0.000681        0.000032
# 22       0.003322      0.000023         0.000651        0.000019
# 23       0.001731      0.000008         0.000756        0.000018
# 24       0.001433      0.000017         0.000525        0.000001
# 25       0.001396      0.000022         0.000530        0.000019
# 26       0.001590      0.000034         0.000523        0.000001
# 27       0.002925      0.000047         0.000545        0.000022
# 28       0.001462      0.000059         0.000648        0.000039
# 29       0.001044      0.000020         0.000420        0.000029
# 30       0.001873      0.000128         0.000771        0.000034
# 31       0.002013      0.000013         0.000740        0.000011
# 32       0.003416      0.000062         0.000760        0.000021
# 33       0.001791      0.000034         0.000862        0.000040
# 34       0.001457      0.000033         0.000621        0.000018
# 35       0.001407      0.000026         0.000618        0.000016
# 36       0.001672      0.000019         0.000617        0.000004
# 37       0.003039      0.000036         0.000647        0.000028
# 38       0.001476      0.000047         0.000753        0.000021
# 39       0.001020      0.000047         0.000483        0.000023
# 40       0.001497      0.000086         0.002427        0.000197
# 41       0.001682      0.000214         0.002432        0.000051
# 42       0.002827      0.000066         0.002345        0.000053
# 43       0.001423      0.000054         0.002411        0.000085
# 44       0.001091      0.000015         0.002267        0.000052
# 45       0.001043      0.000012         0.002245        0.000058
# 46       0.001251      0.000022         0.002176        0.000042
# 47       0.002436      0.000031         0.002209        0.000040
# 48       0.001095      0.000020         0.002267        0.000033
# 49       0.000763      0.000022         0.002077        0.000022
#
#                                      param_classifier  \
# 0   LogisticRegression(max_iter=10000, solver='saga')
# 1   LogisticRegression(max_iter=10000, solver='saga')
# 2   LogisticRegression(max_iter=10000, solver='saga')
# 3   LogisticRegression(max_iter=10000, solver='saga')
# 4   LogisticRegression(max_iter=10000, solver='saga')
# 5   LogisticRegression(max_iter=10000, solver='saga')
# 6   LogisticRegression(max_iter=10000, solver='saga')
# 7   LogisticRegression(max_iter=10000, solver='saga')
# 8   LogisticRegression(max_iter=10000, solver='saga')
# 9   LogisticRegression(max_iter=10000, solver='saga')
# 10  LogisticRegression(max_iter=10000, solver='saga')
# 11  LogisticRegression(max_iter=10000, solver='saga')
# 12  LogisticRegression(max_iter=10000, solver='saga')
# 13  LogisticRegression(max_iter=10000, solver='saga')
# 14  LogisticRegression(max_iter=10000, solver='saga')
# 15  LogisticRegression(max_iter=10000, solver='saga')
# 16  LogisticRegression(max_iter=10000, solver='saga')
# 17  LogisticRegression(max_iter=10000, solver='saga')
# 18  LogisticRegression(max_iter=10000, solver='saga')
# 19  LogisticRegression(max_iter=10000, solver='saga')
# 20             DecisionTreeClassifier(random_state=0)
# 21             DecisionTreeClassifier(random_state=0)
# 22             DecisionTreeClassifier(random_state=0)
# 23             DecisionTreeClassifier(random_state=0)
# 24             DecisionTreeClassifier(random_state=0)
# 25             DecisionTreeClassifier(random_state=0)
# 26             DecisionTreeClassifier(random_state=0)
# 27             DecisionTreeClassifier(random_state=0)
# 28             DecisionTreeClassifier(random_state=0)
# 29             DecisionTreeClassifier(random_state=0)
# 30                                              SVC()
# 31                                              SVC()
# 32                                              SVC()
# 33                                              SVC()
# 34                                              SVC()
# 35                                              SVC()
# 36                                              SVC()
# 37                                              SVC()
# 38                                              SVC()
# 39                                              SVC()
# 40                             KNeighborsClassifier()
# 41                             KNeighborsClassifier()
# 42                             KNeighborsClassifier()
# 43                             KNeighborsClassifier()
# 44                             KNeighborsClassifier()
# 45                             KNeighborsClassifier()
# 46                             KNeighborsClassifier()
# 47                             KNeighborsClassifier()
# 48                             KNeighborsClassifier()
# 49                             KNeighborsClassifier()
#
#    param_classifier__penalty param_predprocessing_pca  \
# 0                         l1      PCA(n_components=2)
# 1                         l1      PCA(n_components=2)
# 2                         l1      PCA(n_components=2)
# 3                         l1      PCA(n_components=2)
# 4                         l1      PCA(n_components=2)
# 5                         l1                     None
# 6                         l1                     None
# 7                         l1                     None
# 8                         l1                     None
# 9                         l1                     None
# 10                        l2      PCA(n_components=2)
# 11                        l2      PCA(n_components=2)
# 12                        l2      PCA(n_components=2)
# 13                        l2      PCA(n_components=2)
# 14                        l2      PCA(n_components=2)
# 15                        l2                     None
# 16                        l2                     None
# 17                        l2                     None
# 18                        l2                     None
# 19                        l2                     None
# 20                       NaN      PCA(n_components=2)
# 21                       NaN      PCA(n_components=2)
# 22                       NaN      PCA(n_components=2)
# 23                       NaN      PCA(n_components=2)
# 24                       NaN      PCA(n_components=2)
# 25                       NaN                     None
# 26                       NaN                     None
# 27                       NaN                     None
# 28                       NaN                     None
# 29                       NaN                     None
# 30                       NaN      PCA(n_components=2)
# 31                       NaN      PCA(n_components=2)
# 32                       NaN      PCA(n_components=2)
# 33                       NaN      PCA(n_components=2)
# 34                       NaN      PCA(n_components=2)
# 35                       NaN                     None
# 36                       NaN                     None
# 37                       NaN                     None
# 38                       NaN                     None
# 39                       NaN                     None
# 40                       NaN      PCA(n_components=2)
# 41                       NaN      PCA(n_components=2)
# 42                       NaN      PCA(n_components=2)
# 43                       NaN      PCA(n_components=2)
# 44                       NaN      PCA(n_components=2)
# 45                       NaN                     None
# 46                       NaN                     None
# 47                       NaN                     None
# 48                       NaN                     None
# 49                       NaN                     None
#
#    param_preprocessing_scaling  \
# 0               MinMaxScaler()
# 1             StandardScaler()
# 2               RobustScaler()
# 3                 Normalizer()
# 4                         None
# 5               MinMaxScaler()
# 6             StandardScaler()
# 7               RobustScaler()
# 8                 Normalizer()
# 9                         None
# 10              MinMaxScaler()
# 11            StandardScaler()
# 12              RobustScaler()
# 13                Normalizer()
# 14                        None
# 15              MinMaxScaler()
# 16            StandardScaler()
# 17              RobustScaler()
# 18                Normalizer()
# 19                        None
# 20              MinMaxScaler()
# 21            StandardScaler()
# 22              RobustScaler()
# 23                Normalizer()
# 24                        None
# 25              MinMaxScaler()
# 26            StandardScaler()
# 27              RobustScaler()
# 28                Normalizer()
# 29                        None
# 30              MinMaxScaler()
# 31            StandardScaler()
# 32              RobustScaler()
# 33                Normalizer()
# 34                        None
# 35              MinMaxScaler()
# 36            StandardScaler()
# 37              RobustScaler()
# 38                Normalizer()
# 39                        None
# 40              MinMaxScaler()
# 41            StandardScaler()
# 42              RobustScaler()
# 43                Normalizer()
# 44                        None
# 45              MinMaxScaler()
# 46            StandardScaler()
# 47              RobustScaler()
# 48                Normalizer()
# 49                        None
#
#                                                params  split0_test_score  \
# 0   {'classifier': LogisticRegression(max_iter=100...           0.956522
# 1   {'classifier': LogisticRegression(max_iter=100...           0.956522
# 2   {'classifier': LogisticRegression(max_iter=100...           0.913043
# 3   {'classifier': LogisticRegression(max_iter=100...           0.956522
# 4   {'classifier': LogisticRegression(max_iter=100...           1.000000
# 5   {'classifier': LogisticRegression(max_iter=100...           0.956522
# 6   {'classifier': LogisticRegression(max_iter=100...           0.956522
# 7   {'classifier': LogisticRegression(max_iter=100...           0.956522
# 8   {'classifier': LogisticRegression(max_iter=100...           0.695652
# 9   {'classifier': LogisticRegression(max_iter=100...           1.000000
# 10  {'classifier': LogisticRegression(max_iter=100...           0.869565
# 11  {'classifier': LogisticRegression(max_iter=100...           0.956522
# 12  {'classifier': LogisticRegression(max_iter=100...           0.869565
# 13  {'classifier': LogisticRegression(max_iter=100...           0.695652
# 14  {'classifier': LogisticRegression(max_iter=100...           1.000000
# 15  {'classifier': LogisticRegression(max_iter=100...           0.869565
# 16  {'classifier': LogisticRegression(max_iter=100...           0.956522
# 17  {'classifier': LogisticRegression(max_iter=100...           0.869565
# 18  {'classifier': LogisticRegression(max_iter=100...           0.695652
# 19  {'classifier': LogisticRegression(max_iter=100...           1.000000
# 20  {'classifier': DecisionTreeClassifier(random_s...           1.000000
# 21  {'classifier': DecisionTreeClassifier(random_s...           0.869565
# 22  {'classifier': DecisionTreeClassifier(random_s...           0.826087
# 23  {'classifier': DecisionTreeClassifier(random_s...           0.956522
# 24  {'classifier': DecisionTreeClassifier(random_s...           0.913043
# 25  {'classifier': DecisionTreeClassifier(random_s...           1.000000
# 26  {'classifier': DecisionTreeClassifier(random_s...           1.000000
# 27  {'classifier': DecisionTreeClassifier(random_s...           1.000000
# 28  {'classifier': DecisionTreeClassifier(random_s...           0.956522
# 29  {'classifier': DecisionTreeClassifier(random_s...           1.000000
# 30  {'classifier': SVC(), 'predprocessing_pca': PC...           1.000000
# 31  {'classifier': SVC(), 'predprocessing_pca': PC...           0.913043
# 32  {'classifier': SVC(), 'predprocessing_pca': PC...           0.913043
# 33  {'classifier': SVC(), 'predprocessing_pca': PC...           1.000000
# 34  {'classifier': SVC(), 'predprocessing_pca': PC...           1.000000
# 35  {'classifier': SVC(), 'predprocessing_pca': No...           0.956522
# 36  {'classifier': SVC(), 'predprocessing_pca': No...           0.956522
# 37  {'classifier': SVC(), 'predprocessing_pca': No...           0.956522
# 38  {'classifier': SVC(), 'predprocessing_pca': No...           1.000000
# 39  {'classifier': SVC(), 'predprocessing_pca': No...           1.000000
# 40  {'classifier': KNeighborsClassifier(), 'predpr...           0.956522
# 41  {'classifier': KNeighborsClassifier(), 'predpr...           0.956522
# 42  {'classifier': KNeighborsClassifier(), 'predpr...           0.913043
# 43  {'classifier': KNeighborsClassifier(), 'predpr...           1.000000
# 44  {'classifier': KNeighborsClassifier(), 'predpr...           1.000000
# 45  {'classifier': KNeighborsClassifier(), 'predpr...           0.956522
# 46  {'classifier': KNeighborsClassifier(), 'predpr...           0.956522
# 47  {'classifier': KNeighborsClassifier(), 'predpr...           0.913043
# 48  {'classifier': KNeighborsClassifier(), 'predpr...           1.000000
# 49  {'classifier': KNeighborsClassifier(), 'predpr...           1.000000
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.869565           1.000000           0.909091
# 1            0.782609           0.954545           0.863636
# 2            0.695652           0.909091           0.818182
# 3            0.869565           0.863636           0.909091
# 4            0.913043           1.000000           0.863636
# 5            0.956522           1.000000           0.954545
# 6            0.913043           1.000000           0.954545
# 7            0.869565           1.000000           0.954545
# 8            0.739130           0.727273           0.772727
# 9            0.956522           1.000000           0.909091
# 10           0.869565           0.954545           0.863636
# 11           0.782609           0.954545           0.863636
# 12           0.739130           0.909091           0.772727
# 13           0.695652           0.681818           0.681818
# 14           0.913043           1.000000           0.863636
# 15           0.869565           0.954545           0.909091
# 16           0.913043           0.954545           0.954545
# 17           0.782609           1.000000           0.954545
# 18           0.695652           0.681818           0.681818
# 19           0.956522           1.000000           0.909091
# 20           0.956522           0.954545           0.909091
# 21           0.913043           0.909091           0.863636
# 22           0.782609           0.863636           0.909091
# 23           1.000000           1.000000           0.954545
# 24           0.956522           1.000000           0.863636
# 25           0.956522           1.000000           0.909091
# 26           0.956522           1.000000           0.909091
# 27           0.956522           1.000000           0.909091
# 28           0.913043           0.954545           0.909091
# 29           0.956522           1.000000           0.909091
# 30           0.869565           0.954545           0.863636
# 31           0.739130           0.954545           0.863636
# 32           0.782609           0.954545           0.818182
# 33           1.000000           0.954545           0.954545
# 34           0.956522           0.954545           0.863636
# 35           0.956522           1.000000           0.954545
# 36           0.869565           1.000000           0.954545
# 37           0.869565           1.000000           0.909091
# 38           1.000000           0.954545           0.954545
# 39           0.956522           1.000000           0.909091
# 40           0.913043           0.954545           0.863636
# 41           0.913043           0.909091           0.863636
# 42           0.826087           0.863636           0.863636
# 43           1.000000           1.000000           0.954545
# 44           0.956522           0.954545           0.909091
# 45           0.913043           1.000000           0.909091
# 46           0.956522           1.000000           0.863636
# 47           0.869565           1.000000           0.909091
# 48           1.000000           1.000000           0.954545
# 49           0.956522           0.954545           0.863636
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            1.000000         0.947036        0.051268               25
# 1            0.954545         0.902372        0.069599               37
# 2            0.954545         0.858103        0.092632               45
# 3            0.909091         0.901581        0.033455               40
# 4            1.000000         0.955336        0.056890               19
# 5            0.954545         0.964427        0.017809                6
# 6            0.954545         0.955731        0.027515               17
# 7            0.954545         0.947036        0.042449               25
# 8            0.772727         0.741502        0.029190               48
# 9            0.954545         0.964032        0.033918                8
# 10           0.909091         0.893281        0.034661               41
# 11           0.954545         0.902372        0.069599               37
# 12           0.909091         0.839921        0.070882               47
# 13           0.727273         0.696443        0.016610               49
# 14           1.000000         0.955336        0.056890               19
# 15           0.954545         0.911462        0.038023               36
# 16           0.954545         0.946640        0.016816               28
# 17           0.954545         0.912253        0.077339               35
# 18           0.727273         0.696443        0.016610               49
# 19           0.954545         0.964032        0.033918                8
# 20           1.000000         0.964032        0.033918                8
# 21           0.954545         0.901976        0.033036               39
# 22           0.909091         0.858103        0.048897               46
# 23           1.000000         0.982213        0.021793                1
# 24           1.000000         0.946640        0.052556               28
# 25           0.954545         0.964032        0.033918                8
# 26           0.954545         0.964032        0.033918                8
# 27           0.954545         0.964032        0.033918                8
# 28           0.954545         0.937549        0.021671               31
# 29           0.954545         0.964032        0.033918                8
# 30           1.000000         0.937549        0.060289               31
# 31           0.954545         0.884980        0.080242               42
# 32           0.909091         0.875494        0.064343               43
# 33           0.954545         0.972727        0.022268                4
# 34           1.000000         0.954941        0.049799               22
# 35           0.954545         0.964427        0.017809                6
# 36           1.000000         0.956126        0.047635               16
# 37           1.000000         0.947036        0.051268               25
# 38           0.954545         0.972727        0.022268                4
# 39           0.954545         0.964032        0.033918                8
# 40           1.000000         0.937549        0.046071               31
# 41           0.954545         0.919368        0.034262               34
# 42           0.909091         0.875099        0.032435               44
# 43           0.954545         0.981818        0.022268                2
# 44           0.954545         0.954941        0.028759               22
# 45           1.000000         0.955731        0.039794               17
# 46           1.000000         0.955336        0.049802               19
# 47           1.000000         0.938340        0.052591               30
# 48           0.954545         0.981818        0.022268                2
# 49           1.000000         0.954941        0.049799               22
