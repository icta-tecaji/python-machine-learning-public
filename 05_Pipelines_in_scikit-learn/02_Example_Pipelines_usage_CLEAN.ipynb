# %% [markdown]
# # Example: Pipelines usage

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('data/house_train.csv')
X_test = pd.read_csv('data/house_test.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# Before we do anything, let's divide up the training data into train and validation sets. We will use the final X_test set for predictions.

# %%
from sklearn.model_selection import train_test_split

X = train.drop('SalePrice', axis=1)
y = train["SalePrice"]

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=.3, random_state=1121218)

# %%
X_train.describe().T.iloc[:10] # All numerical cols
# Out:
#                count          mean          std     min     25%     50%  \
# Id            1022.0    728.628180   417.491868     1.0   374.5   734.5
# MSSubClass    1022.0     57.030333    42.861210    20.0    20.0    50.0
# LotFrontage    838.0     70.190931    24.110495    21.0    60.0    70.0
# LotArea       1022.0  10472.601761  8782.768055  1491.0  7560.0  9571.0
# OverallQual   1022.0      6.071429     1.374094     1.0     5.0     6.0
# OverallCond   1022.0      5.578278     1.101703     1.0     5.0     5.0
# YearBuilt     1022.0   1971.221135    29.863975  1875.0  1954.0  1973.0
# YearRemodAdd  1022.0   1984.813112    20.671520  1950.0  1966.0  1994.0
# MasVnrArea    1015.0    101.768473   180.299391     0.0     0.0     0.0
# BsmtFinSF1    1022.0    441.294521   438.430750     0.0     0.0   381.0
#
#                    75%       max
# Id             1082.00    1459.0
# MSSubClass       70.00     190.0
# LotFrontage      80.00     313.0
# LotArea       11742.50  164660.0
# OverallQual       7.00      10.0
# OverallCond       6.00       9.0
# YearBuilt      2000.00    2009.0
# YearRemodAdd   2003.75    2010.0
# MasVnrArea      160.00    1600.0
# BsmtFinSF1      707.50    2260.0

# %%
X_train.describe(include="object").T.iloc[:10] # All object cols
# Out:
#              count unique     top  freq
# MSZoning      1022      5      RL   809
# Street        1022      2    Pave  1017
# Alley           67      2    Grvl    37
# LotShape      1022      4     Reg   654
# LandContour   1022      4     Lvl   920
# Utilities     1022      2  AllPub  1021
# LotConfig     1022      5  Inside   733
# LandSlope     1022      3     Gtl   966
# Neighborhood  1022     25   NAmes   156
# Condition1    1022      9    Norm   881

# %%
above_0_missing = X_train.isnull().sum() > 0

# %%
X_train.isnull().sum()[above_0_missing]
# Out:
# LotFrontage      184
# Alley            955
# MasVnrType       622
# MasVnrArea         7
# BsmtQual          30
# BsmtCond          30
# BsmtExposure      31
# BsmtFinType1      30
# BsmtFinType2      31
# Electrical         1
# FireplaceQu      480
# GarageType        58
# GarageYrBlt       58
# GarageFinish      58
# GarageQual        58
# GarageCond        58
# PoolQC          1018
# Fence            821
# MiscFeature      988
# dtype: int64

# %%
numerical_features = X_train.select_dtypes(include='number').columns.tolist()

# %%
print(f'There are {len(numerical_features)} numerical features: {numerical_features}, \n')
# Out:
# There are 37 numerical features: ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold'],

# %%
categorical_features = X_train.select_dtypes(exclude='number').columns.tolist()

# %%
print(f'There are {len(categorical_features)} categorical features: {categorical_features}', '\n')
# Out:
# There are 43 categorical features: ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.pipeline import Pipeline

# %%
numeric_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='mean')),
    ('scale', MinMaxScaler())
])

categorical_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('one-hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# %%
from sklearn.compose import ColumnTransformer

# %%
full_processor = ColumnTransformer(transformers=[
    ('number', numeric_pipeline, numerical_features),
    ('category', categorical_pipeline, categorical_features)
])

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error

# %%
lasso = Lasso(alpha=0.1)

lasso_pipeline = Pipeline(steps=[
    ('preprocess', full_processor),
    ('model', lasso)
])

lasso_pipeline.fit(X_train, y_train)
# Out:
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.582e+10, tolerance: 6.094e+08
#   model = cd_fast.enet_coordinate_descent(
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('number',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    MinMaxScaler())]),
#                                                   ['Id', 'MSSubClass',
#                                                    'LotFrontage', 'LotArea',
#                                                    'OverallQual', 'OverallCond',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
#                                                    'TotalBsmtSF', '1stFlrSF',
#                                                    '2ndFlrSF', 'LowQualFinSF',
#                                                    'GrLivAr...
#                                                    'LandContour', 'Utilities',
#                                                    'LotConfig', 'LandSlope',
#                                                    'Neighborhood', 'Condition1',
#                                                    'Condition2', 'BldgType',
#                                                    'HouseStyle', 'RoofStyle',
#                                                    'RoofMatl', 'Exterior1st',
#                                                    'Exterior2nd', 'MasVnrType',
#                                                    'ExterQual', 'ExterCond',
#                                                    'Foundation', 'BsmtQual',
#                                                    'BsmtCond', 'BsmtExposure',
#                                                    'BsmtFinType1',
#                                                    'BsmtFinType2', 'Heating',
#                                                    'HeatingQC', 'CentralAir',
#                                                    'Electrical', ...])])),
#                 ('model', Lasso(alpha=0.1))])

# %%
preds = lasso_pipeline.predict(X_valid)

# %%
mean_absolute_error(y_valid, preds)
# Out:
# 19827.45940110742

# %%
lasso_pipeline.score(X_valid, y_valid)
# Out:
# 0.7069796202127815

# %%
def run_training(data, model):
    X = data.drop('SalePrice', axis=1)
    y = data["SalePrice"]
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=.3, random_state=1121218)
    
    numerical_features = X_train.select_dtypes(include='number').columns.tolist()
    categorical_features = X_train.select_dtypes(exclude='number').columns.tolist()
    
    # pipeline
    numeric_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='mean')),
        ('scale', MinMaxScaler())
    ])
    categorical_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='most_frequent')),
        ('one-hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
    ])  
    full_processor = ColumnTransformer(transformers=[
        ('number', numeric_pipeline, numerical_features),
        ('category', categorical_pipeline, categorical_features)
    ])
    
    full_pipeline = Pipeline(steps=[
        ('preprocess', full_processor),
        ('model', model)
    ])
    
    full_pipeline.fit(X_train, y_train)
    preds = full_pipeline.predict(X_valid)
    
    print(f"Mean absolute error: {mean_absolute_error(y_valid, preds)}")
    print(f"Score: {lasso_pipeline.score(X_valid, y_valid)}")

# %%
train = pd.read_csv('data/house_train.csv')
lasso = Lasso(alpha=0.1)
run_training(train, lasso)
# Out:
# Mean absolute error: 19827.45940110742
# Score: 0.7069796202127815
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.582e+10, tolerance: 6.094e+08
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# Naloga: Dodajte feature selection v pipeline.

# %%
from sklearn.feature_selection import SelectPercentile, f_regression

# uporaba: SelectPercentile(score_func=f_regression, percentile=80)

def run_training(data, model):
    X = data.drop('SalePrice', axis=1)
    y = data["SalePrice"]
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=.3, random_state=1121218)
    
    numerical_features = X_train.select_dtypes(include='number').columns.tolist()
    categorical_features = X_train.select_dtypes(exclude='number').columns.tolist()
    
    # pipeline
    numeric_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='mean')),
        ('scale', MinMaxScaler())
    ])
    categorical_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='most_frequent')),
        ('one-hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
    ])  
    full_processor = ColumnTransformer(transformers=[
        ('number', numeric_pipeline, numerical_features),
        ('category', categorical_pipeline, categorical_features)
    ])
    
    full_pipeline = Pipeline(steps=[
        ('preprocess', full_processor),
        ("select", SelectPercentile(score_func=f_regression, percentile=80)),
        ('model', model)
    ])
    
    full_pipeline.fit(X_train, y_train)
    preds = full_pipeline.predict(X_valid)
    
    print(f"Mean absolute error: {mean_absolute_error(y_valid, preds)}")
    print(f"Score: {full_pipeline.score(X_valid, y_valid)}")
    return full_pipeline
    
train = pd.read_csv('data/house_train.csv')
lasso = Lasso(alpha=0.1)
run_training(train, lasso)
# Out:
# Mean absolute error: 19336.801941618458
# Score: 0.7873358035432518
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.689e+10, tolerance: 6.094e+08
#   model = cd_fast.enet_coordinate_descent(
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('number',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    MinMaxScaler())]),
#                                                   ['Id', 'MSSubClass',
#                                                    'LotFrontage', 'LotArea',
#                                                    'OverallQual', 'OverallCond',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
#                                                    'TotalBsmtSF', '1stFlrSF',
#                                                    '2ndFlrSF', 'LowQualFinSF',
#                                                    'GrLivAr...
#                                                    'HouseStyle', 'RoofStyle',
#                                                    'RoofMatl', 'Exterior1st',
#                                                    'Exterior2nd', 'MasVnrType',
#                                                    'ExterQual', 'ExterCond',
#                                                    'Foundation', 'BsmtQual',
#                                                    'BsmtCond', 'BsmtExposure',
#                                                    'BsmtFinType1',
#                                                    'BsmtFinType2', 'Heating',
#                                                    'HeatingQC', 'CentralAir',
#                                                    'Electrical', ...])])),
#                 ('select',
#                  SelectPercentile(percentile=80,
#                                   score_func=<function f_regression at 0x7fdf49811a80>)),
#                 ('model', Lasso(alpha=0.1))])

# %%
from sklearn.model_selection import GridSearchCV

param_dict = {'model__alpha': np.arange(0.01, 1, 0.05)}

search = GridSearchCV(lasso_pipeline, param_dict, 
                      cv=10, 
                      scoring='neg_mean_absolute_error')

search.fit(X_train, y_train)
# Out:
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.866e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.022e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.753e+10, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.091e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.871e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.126e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.873e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.503e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.044e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.716e+10, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.128e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.643e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.680e+10, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.127e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.210e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.558e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.926e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.519e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.285e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.410e+10, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.185e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.415e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.704e+10, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.824e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.019e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.097e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.958e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.520e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.386e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.552e+10, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.846e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.427e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.991e+10, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.843e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.294e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.800e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.049e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.529e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.840e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.859e+10, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.205e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.435e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.999e+10, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.862e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.317e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.847e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.066e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.544e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.907e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.984e+09, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.276e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.945e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.015e+10, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.884e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.215e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.943e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.071e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.959e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.846e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.595e+09, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.282e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.952e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.350e+10, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.820e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.222e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.866e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.059e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.974e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.862e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.541e+09, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.295e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.293e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.148e+09, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.833e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.226e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.991e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.919e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.982e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.872e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.278e+09, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.204e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.303e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.174e+09, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.767e+09, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.457e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.004e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.919e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.990e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.278e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.460e+09, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.111e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.308e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.962e+09, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.203e+09, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.781e+09, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.009e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.880e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.073e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.258e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.566e+09, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.144e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.310e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.340e+09, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.251e+09, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.657e+09, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.013e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.940e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.078e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.265e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.595e+09, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.174e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.327e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.977e+08, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.303e+09, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.251e+09, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.013e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.322e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.082e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.355e+09, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.619e+09, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.195e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.035e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.944e+09, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.962e+09, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.669e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.355e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.486e+09, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.897e+09, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.262e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.988e+09, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.005e+09, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.495e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.364e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.528e+09, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.570e+09, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.978e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.931e+09, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.044e+09, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.366e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.371e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.888e+09, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.159e+09, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.429e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.980e+09, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.084e+09, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.149e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.377e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.574e+09, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.065e+09, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.449e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.065e+09, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.124e+09, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.095e+09, tolerance: 6.094e+08
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('number',
#                                                                          Pipeline(steps=[('impute',
#                                                                                           SimpleImputer()),
#                                                                                          ('scale',
#                                                                                           MinMaxScaler())]),
#                                                                          ['Id',
#                                                                           'MSSubClass',
#                                                                           'LotFrontage',
#                                                                           'LotArea',
#                                                                           'OverallQual',
#                                                                           'OverallCond',
#                                                                           'YearBuilt',
#                                                                           'YearRemodAdd',
#                                                                           'MasVnrArea',
#                                                                           'BsmtFinSF1',
#                                                                           'BsmtFinSF2',
#                                                                           'BsmtUnfSF',
#                                                                           'TotalBsmtSF',
#                                                                           '1stFlrSF',
#                                                                           '2ndF...
#                                                                           'ExterQual',
#                                                                           'ExterCond',
#                                                                           'Foundation',
#                                                                           'BsmtQual',
#                                                                           'BsmtCond',
#                                                                           'BsmtExposure',
#                                                                           'BsmtFinType1',
#                                                                           'BsmtFinType2',
#                                                                           'Heating',
#                                                                           'HeatingQC',
#                                                                           'CentralAir',
#                                                                           'Electrical', ...])])),
#                                        ('model', Lasso(alpha=0.1))]),
#              param_grid={'model__alpha': array([0.01, 0.06, 0.11, 0.16, 0.21, 0.26, 0.31, 0.36, 0.41, 0.46, 0.51,
#        0.56, 0.61, 0.66, 0.71, 0.76, 0.81, 0.86, 0.91, 0.96])},
#              scoring='neg_mean_absolute_error')

# %%
print('Best score:', abs(search.best_score_))
print('Best alpha:', search.best_params_)
# Out:
# Best score: 18196.268521979895
# Best alpha: {'model__alpha': 0.9600000000000001}

# %%
param_dict = {'model__alpha': np.arange(1, 100, 5)}

search = GridSearchCV(lasso_pipeline, param_dict, 
                      cv=5, 
                      scoring='neg_mean_absolute_error')

search.fit(X_train, y_train)

print('Best score:', abs(search.best_score_))
print('Best alpha:', search.best_params_)
# Out:
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.326e+09, tolerance: 4.800e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.829e+08, tolerance: 5.079e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.773e+09, tolerance: 4.852e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.375e+09, tolerance: 4.813e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.251e+09, tolerance: 5.079e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.587e+08, tolerance: 4.852e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.654e+08, tolerance: 4.852e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.744e+09, tolerance: 4.852e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.217e+08, tolerance: 4.800e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.712e+08, tolerance: 4.800e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.135e+08, tolerance: 4.800e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-machine-learning-public/.venv/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.665e+08, tolerance: 4.800e+08
#   model = cd_fast.enet_coordinate_descent(
# Best score: 16440.07047519717
# Best alpha: {'model__alpha': 86}

# %%
def run_training_gridcv(data, model, params):
    X = data.drop('SalePrice', axis=1)
    y = data["SalePrice"]
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=.3, random_state=1121218)
    
    numerical_features = X_train.select_dtypes(include='number').columns.tolist()
    categorical_features = X_train.select_dtypes(exclude='number').columns.tolist()
    
    # pipeline
    numeric_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='mean')),
        ('scale', MinMaxScaler())
    ])
    categorical_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='most_frequent')),
        ('one-hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
    ])  
    full_processor = ColumnTransformer(transformers=[
        ('number', numeric_pipeline, numerical_features),
        ('category', categorical_pipeline, categorical_features)
    ])
    
    full_pipeline = Pipeline(steps=[
        ('preprocess', full_processor),
        ("select", SelectPercentile(score_func=f_regression, percentile=80)),
        ('model', model)
    ])
    
    
    search = GridSearchCV(full_pipeline, params, 
                      cv=5, 
                      scoring='neg_mean_absolute_error')
    
    search.fit(X_train, y_train)

    print('Best score:', abs(search.best_score_))
    print('Best params:', search.best_params_)
    return search
    
train = pd.read_csv('data/house_train.csv')
param_dict = {'model__alpha': np.arange(1, 300, 10)}
lasso = Lasso(alpha=0.1)
run_training_gridcv(train, lasso, param_dict)

# %%
lasso = Lasso(alpha=151)

final_lasso_pipe = Pipeline(steps=[
    ('preprocess', full_processor),
    ('model', lasso)
])

final_lasso_pipe.fit(X_train, y_train)
preds = final_lasso_pipe.predict(X_valid)

mean_absolute_error(y_valid, preds)

# %%
preds_final = final_lasso_pipe.predict(X_test)

output = pd.DataFrame({'Id': X_test["Id"], 'SalePrice': preds_final})
output.head()
