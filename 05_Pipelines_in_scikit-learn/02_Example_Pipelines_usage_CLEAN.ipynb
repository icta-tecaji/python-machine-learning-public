# %% [markdown]
# # Example: Pipelines usage

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('data/house_train.csv')
X_test = pd.read_csv('data/house_test.csv')

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split

X = train.drop('SalePrice', axis=1)
y = train["SalePrice"]

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=.3, random_state=1121218)

# %%
X.shape
# Out:
# (1460, 80)

# %%
y.min()
# Out:
# 34900

# %%
y.max()
# Out:
# 755000

# %%
y.mean()
# Out:
# 180921.19589041095

# %%
X_train.head()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 721    722         120       RM          NaN     4426   Pave   NaN      Reg
# 925    926          20       RL          NaN    15611   Pave   NaN      IR1
# 773    774          20       RL         70.0    10150   Pave   NaN      Reg
# 1024  1025          20       RL          NaN    15498   Pave   NaN      IR1
# 799    800          50       RL         60.0     7200   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 721          Lvl    AllPub  ...           0        0    NaN    NaN
# 925          Lvl    AllPub  ...           0        0    NaN    NaN
# 773          Lvl    AllPub  ...           0        0    NaN    NaN
# 1024         Lvl    AllPub  ...           0        0    NaN    NaN
# 799          Lvl    AllPub  ...           0        0    NaN  MnPrv
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 721          NaN       0      5    2010        WD         Normal
# 925          NaN       0      3    2008        WD        Abnorml
# 773          NaN       0      7    2007       COD         Normal
# 1024         NaN       0      5    2008       COD        Abnorml
# 799          NaN       0      6    2007        WD         Normal
#
# [5 rows x 80 columns]

# %%
X_train.describe().T.iloc[:10] # All numerical cols
# Out:
#                count          mean          std     min     25%     50%  \
# Id            1022.0    728.628180   417.491868     1.0   374.5   734.5
# MSSubClass    1022.0     57.030333    42.861210    20.0    20.0    50.0
# LotFrontage    838.0     70.190931    24.110495    21.0    60.0    70.0
# LotArea       1022.0  10472.601761  8782.768055  1491.0  7560.0  9571.0
# OverallQual   1022.0      6.071429     1.374094     1.0     5.0     6.0
# OverallCond   1022.0      5.578278     1.101703     1.0     5.0     5.0
# YearBuilt     1022.0   1971.221135    29.863975  1875.0  1954.0  1973.0
# YearRemodAdd  1022.0   1984.813112    20.671520  1950.0  1966.0  1994.0
# MasVnrArea    1015.0    101.768473   180.299391     0.0     0.0     0.0
# BsmtFinSF1    1022.0    441.294521   438.430750     0.0     0.0   381.0
#
#                    75%       max
# Id             1082.00    1459.0
# MSSubClass       70.00     190.0
# LotFrontage      80.00     313.0
# LotArea       11742.50  164660.0
# OverallQual       7.00      10.0
# OverallCond       6.00       9.0
# YearBuilt      2000.00    2009.0
# YearRemodAdd   2003.75    2010.0
# MasVnrArea      160.00    1600.0
# BsmtFinSF1      707.50    2260.0

# %%
X_train.describe(include="object").T.iloc[:10] # All object cols
# Out:
#              count unique     top  freq
# MSZoning      1022      5      RL   809
# Street        1022      2    Pave  1017
# Alley           67      2    Grvl    37
# LotShape      1022      4     Reg   654
# LandContour   1022      4     Lvl   920
# Utilities     1022      2  AllPub  1021
# LotConfig     1022      5  Inside   733
# LandSlope     1022      3     Gtl   966
# Neighborhood  1022     25   NAmes   156
# Condition1    1022      9    Norm   881

# %%
above_0_missing = X_train.isnull().sum() > 0

# %%
X_train.isnull().sum()[above_0_missing]
# Out:
# LotFrontage      184
# Alley            955
# MasVnrType         7
# MasVnrArea         7
# BsmtQual          30
# BsmtCond          30
# BsmtExposure      31
# BsmtFinType1      30
# BsmtFinType2      31
# Electrical         1
# FireplaceQu      480
# GarageType        58
# GarageYrBlt       58
# GarageFinish      58
# GarageQual        58
# GarageCond        58
# PoolQC          1018
# Fence            821
# MiscFeature      988
# dtype: int64

# %%
numerical_features = X_train.select_dtypes(include='number').columns.tolist()

# %%
print(f'There are {len(numerical_features)} numerical features:', '\n')
# Out:
# There are 37 numerical features:

# %%
print(numerical_features)
# Out:
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
categorical_features = X_train.select_dtypes(exclude='number').columns.tolist()

# %%
print(f'There are {len(categorical_features)} categorical features:', '\n')
# Out:
# There are 43 categorical features:

# %%
print(categorical_features)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.pipeline import Pipeline

# %%
numeric_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='mean')),
    ('scale', MinMaxScaler())
])

categorical_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('one-hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# %%
from sklearn.compose import ColumnTransformer

# %%
full_processor = ColumnTransformer(transformers=[
    ('number', numeric_pipeline, numerical_features),
    ('category', categorical_pipeline, categorical_features)
])

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error

# %%
lasso = Lasso(alpha=0.1)

lasso_pipeline = Pipeline(steps=[
    ('preprocess', full_processor),
    ('model', lasso)
])

lasso_pipeline.fit(X_train, y_train)
# Out:
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.476e+10, tolerance: 6.094e+08
#   model = cd_fast.enet_coordinate_descent(
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('number',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    MinMaxScaler())]),
#                                                   ['Id', 'MSSubClass',
#                                                    'LotFrontage', 'LotArea',
#                                                    'OverallQual', 'OverallCond',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
#                                                    'TotalBsmtSF', '1stFlrSF',
#                                                    '2ndFlrSF', 'LowQualFinSF',
#                                                    'GrLivAr...
#                                                    'LandContour', 'Utilities',
#                                                    'LotConfig', 'LandSlope',
#                                                    'Neighborhood', 'Condition1',
#                                                    'Condition2', 'BldgType',
#                                                    'HouseStyle', 'RoofStyle',
#                                                    'RoofMatl', 'Exterior1st',
#                                                    'Exterior2nd', 'MasVnrType',
#                                                    'ExterQual', 'ExterCond',
#                                                    'Foundation', 'BsmtQual',
#                                                    'BsmtCond', 'BsmtExposure',
#                                                    'BsmtFinType1',
#                                                    'BsmtFinType2', 'Heating',
#                                                    'HeatingQC', 'CentralAir',
#                                                    'Electrical', ...])])),
#                 ('model', Lasso(alpha=0.1))])

# %%
preds = lasso_pipeline.predict(X_valid)

# %%
mean_absolute_error(y_valid, preds)
# Out:
# 19830.527070323806

# %%
lasso_pipeline.score(X_valid, y_valid)
# Out:
# 0.7079758134752534

# %%
def run_training(data, model):
    X = data.drop('SalePrice', axis=1)
    y = data["SalePrice"]
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=.3, random_state=1121218)
    
    numerical_features = X_train.select_dtypes(include='number').columns.tolist()
    categorical_features = X_train.select_dtypes(exclude='number').columns.tolist()
    
    # pipeline
    numeric_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='mean')),
        ('scale', MinMaxScaler())
    ])
    categorical_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='most_frequent')),
        ('one-hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
    ])  
    full_processor = ColumnTransformer(transformers=[
        ('number', numeric_pipeline, numerical_features),
        ('category', categorical_pipeline, categorical_features)
    ])
    
    full_pipeline = Pipeline(steps=[
        ('preprocess', full_processor),
        ('model', model)
    ])
    
    full_pipeline.fit(X_train, y_train)
    preds = full_pipeline.predict(X_valid)
    
    print(f"Mean absolute error: {mean_absolute_error(y_valid, preds)}")
    print(f"Score: {full_pipeline.score(X_valid, y_valid)}")

# %%
from sklearn.linear_model import Ridge

train = pd.read_csv('data/house_train.csv')
lasso = Lasso(alpha=0.1)
run_training(train, lasso)
# Out:
# Mean absolute error: 19329.640159129493
# Score: 0.7883839728739456
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.561e+10, tolerance: 6.094e+08
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# Naloga: Dodajte feature selection v pipeline.

# %%
from sklearn.feature_selection import SelectPercentile, f_regression

def run_training(data, model):
    X = data.drop('SalePrice', axis=1)
    y = data["SalePrice"]
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=.3, random_state=1121218)
    
    numerical_features = X_train.select_dtypes(include='number').columns.tolist()
    categorical_features = X_train.select_dtypes(exclude='number').columns.tolist()
    
    # pipeline
    numeric_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='mean')),
        ('scale', MinMaxScaler())
    ])
    categorical_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='most_frequent')),
        ('one-hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
    ])  
    full_processor = ColumnTransformer(transformers=[
        ('number', numeric_pipeline, numerical_features),
        ('category', categorical_pipeline, categorical_features)
    ])
    
    full_pipeline = Pipeline(steps=[
        ('preprocess', full_processor),
        ('select', SelectPercentile(score_func=f_regression, percentile=80)),
        ('model', model)
    ])
    
    full_pipeline.fit(X_train, y_train)
    preds = full_pipeline.predict(X_valid)
    
    print(f"Mean absolute error: {mean_absolute_error(y_valid, preds)}")
    print(f"Score: {full_pipeline.score(X_valid, y_valid)}")
    
train = pd.read_csv('data/house_train.csv')
lasso = Lasso(alpha=0.1)
run_training(train, lasso)
# Out:
# Mean absolute error: 19329.640159129493
# Score: 0.7883839728739456
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.561e+10, tolerance: 6.094e+08
#   model = cd_fast.enet_coordinate_descent(

# %%
from sklearn.model_selection import GridSearchCV

param_dict = {'model__alpha': np.arange(0.01, 1, 0.05)}

search = GridSearchCV(lasso_pipeline, param_dict, 
                      cv=10, 
                      scoring='neg_mean_absolute_error')

search.fit(X_train, y_train)
# Out:
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.864e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.515e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.752e+10, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.115e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.813e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.121e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.807e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.503e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.044e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.711e+10, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.075e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.633e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.679e+10, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.040e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.201e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.556e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.931e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.514e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.275e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.400e+10, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.097e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.454e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.686e+10, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.854e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.015e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.163e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.962e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.518e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.351e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.548e+10, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.935e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.477e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.991e+10, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.846e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.790e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.099e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.005e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.526e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.839e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.856e+10, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.288e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.426e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.000e+10, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.017e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.314e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.848e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.674e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.546e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.954e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.865e+10, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.276e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.939e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.979e+10, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.884e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.212e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.938e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.991e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.398e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.994e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.340e+09, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.282e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.946e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.831e+10, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.824e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.220e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.853e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.992e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.971e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.852e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.944e+09, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.295e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.285e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.773e+09, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.834e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.225e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.984e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.911e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.979e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.864e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.689e+09, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.247e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.300e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.770e+09, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.336e+10, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.235e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.003e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.918e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.987e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.295e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.592e+09, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.092e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.301e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.841e+09, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.202e+09, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.807e+10, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.008e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.928e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.074e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.142e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.649e+09, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.113e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.307e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.858e+09, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.252e+09, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.837e+09, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.013e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.937e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.076e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.254e+10, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.605e+09, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.148e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.315e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.104e+09, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.303e+09, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.312e+09, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.017e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.086e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.081e+10, tolerance: 5.577e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.139e+09, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.593e+09, tolerance: 5.520e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.175e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.323e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.940e+08, tolerance: 5.619e+08
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.616e+09, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.725e+09, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.032e+10, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.873e+09, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.946e+09, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.508e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.351e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.516e+09, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.367e+09, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.771e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.921e+09, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.997e+09, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.399e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.358e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.574e+09, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.386e+09, tolerance: 5.563e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.649e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.965e+09, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.034e+09, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.310e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.368e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.659e+09, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.609e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.001e+10, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.075e+09, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.234e+10, tolerance: 5.567e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.372e+10, tolerance: 5.323e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.473e+09, tolerance: 5.561e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.588e+09, tolerance: 5.354e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.445e+09, tolerance: 5.369e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.117e+09, tolerance: 5.386e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.484e+09, tolerance: 6.094e+08
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('number',
#                                                                          Pipeline(steps=[('impute',
#                                                                                           SimpleImputer()),
#                                                                                          ('scale',
#                                                                                           MinMaxScaler())]),
#                                                                          ['Id',
#                                                                           'MSSubClass',
#                                                                           'LotFrontage',
#                                                                           'LotArea',
#                                                                           'OverallQual',
#                                                                           'OverallCond',
#                                                                           'YearBuilt',
#                                                                           'YearRemodAdd',
#                                                                           'MasVnrArea',
#                                                                           'BsmtFinSF1',
#                                                                           'BsmtFinSF2',
#                                                                           'BsmtUnfSF',
#                                                                           'TotalBsmtSF',
#                                                                           '1stFlrSF',
#                                                                           '2ndF...
#                                                                           'ExterQual',
#                                                                           'ExterCond',
#                                                                           'Foundation',
#                                                                           'BsmtQual',
#                                                                           'BsmtCond',
#                                                                           'BsmtExposure',
#                                                                           'BsmtFinType1',
#                                                                           'BsmtFinType2',
#                                                                           'Heating',
#                                                                           'HeatingQC',
#                                                                           'CentralAir',
#                                                                           'Electrical', ...])])),
#                                        ('model', Lasso(alpha=0.1))]),
#              param_grid={'model__alpha': array([0.01, 0.06, 0.11, 0.16, 0.21, 0.26, 0.31, 0.36, 0.41, 0.46, 0.51,
#        0.56, 0.61, 0.66, 0.71, 0.76, 0.81, 0.86, 0.91, 0.96])},
#              scoring='neg_mean_absolute_error')

# %%
print('Best score:', abs(search.best_score_))
print('Best alpha:', search.best_params_)
# Out:
# Best score: 18210.560105627017
# Best alpha: {'model__alpha': 0.9600000000000001}

# %%
param_dict = {'model__alpha': np.arange(1, 100, 5)}

search = GridSearchCV(lasso_pipeline, param_dict, 
                      cv=5, 
                      scoring='neg_mean_absolute_error')

search.fit(X_train, y_train)

print('Best score:', abs(search.best_score_))
print('Best alpha:', search.best_params_)
# Out:
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.535e+09, tolerance: 4.800e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.257e+08, tolerance: 5.079e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.797e+09, tolerance: 4.852e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.745e+09, tolerance: 4.813e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.433e+09, tolerance: 5.079e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.597e+08, tolerance: 4.852e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.673e+08, tolerance: 4.852e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.340e+08, tolerance: 4.852e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.224e+08, tolerance: 4.800e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.722e+08, tolerance: 4.800e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.140e+08, tolerance: 4.800e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.665e+08, tolerance: 4.800e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.202e+08, tolerance: 4.800e+08
#   model = cd_fast.enet_coordinate_descent(
# Best score: 16468.24463894264
# Best alpha: {'model__alpha': 86}

# %%
def run_training_gridcv(data, model, params):
    X = data.drop('SalePrice', axis=1)
    y = data["SalePrice"]
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=.3, random_state=1121218)
    
    numerical_features = X_train.select_dtypes(include='number').columns.tolist()
    categorical_features = X_train.select_dtypes(exclude='number').columns.tolist()
    
    # pipeline
    numeric_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='mean')),
        ('scale', MinMaxScaler())
    ])
    categorical_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='most_frequent')),
        ('one-hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
    ])  
    full_processor = ColumnTransformer(transformers=[
        ('number', numeric_pipeline, numerical_features),
        ('category', categorical_pipeline, categorical_features)
    ])
    
    full_pipeline = Pipeline(steps=[
        ('preprocess', full_processor),
        ("select", SelectPercentile(score_func=f_regression, percentile=80)),
        ('model', model)
    ])
    
    
    search = GridSearchCV(full_pipeline, params, 
                      cv=5, 
                      scoring='neg_mean_absolute_error')
    
    search.fit(X_train, y_train)

    print('Best score:', abs(search.best_score_))
    print('Best params:', search.best_params_)
    return search
    
train = pd.read_csv('data/house_train.csv')
param_dict = {'model__alpha': np.arange(1, 300, 10)}
lasso = Lasso(alpha=0.1)
run_training_gridcv(train, lasso, param_dict)
# Out:
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.078e+10, tolerance: 4.800e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.183e+08, tolerance: 5.079e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.175e+08, tolerance: 4.825e+08
#   model = cd_fast.enet_coordinate_descent(
# Best score: 16934.90461500051
# Best params: {'model__alpha': 151}
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('number',
#                                                                          Pipeline(steps=[('impute',
#                                                                                           SimpleImputer()),
#                                                                                          ('scale',
#                                                                                           MinMaxScaler())]),
#                                                                          ['Id',
#                                                                           'MSSubClass',
#                                                                           'LotFrontage',
#                                                                           'LotArea',
#                                                                           'OverallQual',
#                                                                           'OverallCond',
#                                                                           'YearBuilt',
#                                                                           'YearRemodAdd',
#                                                                           'MasVnrArea',
#                                                                           'BsmtFinSF1',
#                                                                           'BsmtFinSF2',
#                                                                           'BsmtUnfSF',
#                                                                           'TotalBsmtSF',
#                                                                           '1stFlrSF',
#                                                                           '2ndFl...
#                                                                           'Heating',
#                                                                           'HeatingQC',
#                                                                           'CentralAir',
#                                                                           'Electrical', ...])])),
#                                        ('select',
#                                         SelectPercentile(percentile=80,
#                                                          score_func=<function f_regression at 0x7f311ad5ee60>)),
#                                        ('model', Lasso(alpha=0.1))]),
#              param_grid={'model__alpha': array([  1,  11,  21,  31,  41,  51,  61,  71,  81,  91, 101, 111, 121,
#        131, 141, 151, 161, 171, 181, 191, 201, 211, 221, 231, 241, 251,
#        261, 271, 281, 291])},
#              scoring='neg_mean_absolute_error')

# %%
# 1. Naši train podatki
train = pd.read_csv('data/house_train.csv')
X = train.drop('SalePrice', axis=1)
y = train["SalePrice"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=1121218)

# 2. Treniranje našega modela in iskanje parametrov
def run_training_gridcv(X_train, y_train, model, params):    
    numerical_features = X_train.select_dtypes(include='number').columns.tolist()
    categorical_features = X_train.select_dtypes(exclude='number').columns.tolist()
    
    # pipeline
    numeric_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='mean')),
        ('scale', MinMaxScaler())
    ])
    categorical_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='most_frequent')),
        ('one-hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
    ])  
    full_processor = ColumnTransformer(transformers=[
        ('number', numeric_pipeline, numerical_features),
        ('category', categorical_pipeline, categorical_features)
    ])
    
    full_pipeline = Pipeline(steps=[
        ('preprocess', full_processor),
        ("select", SelectPercentile(score_func=f_regression, percentile=80)),
        ('model', model)
    ])
    
    
    search = GridSearchCV(full_pipeline, params, 
                      cv=5, 
                      scoring='neg_mean_absolute_error')
    
    search.fit(X_train, y_train)

    print('Best score:', abs(search.best_score_))
    print('Best params:', search.best_params_)
    return search
    

param_dict = {'model__alpha': np.arange(1, 300, 10)}
lasso = Lasso(alpha=0.1)
run_training_gridcv(X_train, y_train, lasso, param_dict)
# Out:
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.078e+10, tolerance: 4.800e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.183e+08, tolerance: 5.079e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/administrator/python-analitika-2-public/.venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.175e+08, tolerance: 4.825e+08
#   model = cd_fast.enet_coordinate_descent(
# Best score: 16934.90461500051
# Best params: {'model__alpha': 151}
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('number',
#                                                                          Pipeline(steps=[('impute',
#                                                                                           SimpleImputer()),
#                                                                                          ('scale',
#                                                                                           MinMaxScaler())]),
#                                                                          ['Id',
#                                                                           'MSSubClass',
#                                                                           'LotFrontage',
#                                                                           'LotArea',
#                                                                           'OverallQual',
#                                                                           'OverallCond',
#                                                                           'YearBuilt',
#                                                                           'YearRemodAdd',
#                                                                           'MasVnrArea',
#                                                                           'BsmtFinSF1',
#                                                                           'BsmtFinSF2',
#                                                                           'BsmtUnfSF',
#                                                                           'TotalBsmtSF',
#                                                                           '1stFlrSF',
#                                                                           '2ndFl...
#                                                                           'Heating',
#                                                                           'HeatingQC',
#                                                                           'CentralAir',
#                                                                           'Electrical', ...])])),
#                                        ('select',
#                                         SelectPercentile(percentile=80,
#                                                          score_func=<function f_regression at 0x7f311ad5ee60>)),
#                                        ('model', Lasso(alpha=0.1))]),
#              param_grid={'model__alpha': array([  1,  11,  21,  31,  41,  51,  61,  71,  81,  91, 101, 111, 121,
#        131, 141, 151, 161, 171, 181, 191, 201, 211, 221, 231, 241, 251,
#        261, 271, 281, 291])},
#              scoring='neg_mean_absolute_error')

# %%
final_lasso_pipe = Pipeline(steps=[
    ('preprocess', full_processor),
    ('model', Lasso(alpha=151))
])

final_lasso_pipe.fit(X_train, y_train)
preds = final_lasso_pipe.predict(X_test)

mean_absolute_error(y_test, preds)
# Out:
# 17870.072952257688

# %%
X_raw = pd.read_csv('data/house_test.csv')
preds_final = final_lasso_pipe.predict(X_raw)

output = pd.DataFrame({'Id': X_raw["Id"], 'SalePrice': preds_final})
output.head()
# Out:
#      Id      SalePrice
# 0  1461  108175.322829
# 1  1462  161472.124919
# 2  1463  183853.576017
# 3  1464  194416.087478
# 4  1465  200090.933363
